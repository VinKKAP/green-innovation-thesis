# %% [markdown]
# # 04 Interpretation
#
# This notebook interprets model results and derives insights for the thesis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Feature Importance

# %%
# importances = pd.Series(model.feature_importances_, index=X.columns)
# importances.sort_values().plot(kind='barh')
# plt.savefig('../results/figures/feature_importance.png')

# %% [markdown]
# ## Key Findings

# %%
# Summarise key results and export tables
# results_df = pd.DataFrame({'metric': ['R2', 'RMSE'], 'value': [r2, rmse]})
# results_df.to_csv('../results/tables/model_metrics.csv', index=False)

# %% [markdown]
# # 02 Exploration
#
# This notebook performs exploratory data analysis (EDA) on the processed dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Processed Data

# %%
# df = pd.read_csv('../data/processed/data_clean.csv')
# df.describe()

# %% [markdown]
# ## Distribution Analysis

# %%
# plt.figure(figsize=(10, 6))
# sns.histplot(df['variable'])
# plt.savefig('../results/figures/distribution.png')

# %% [markdown]
# ## Correlation Analysis

# %%
# corr = df.corr()
# sns.heatmap(corr)
# plt.savefig('../results/figures/correlation.png')

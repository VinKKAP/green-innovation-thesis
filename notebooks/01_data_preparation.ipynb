# %% [markdown]
# # 01 Data Preparation
#
# This notebook covers loading, cleaning, and preparing raw data for analysis.

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Load Raw Data

# %%
# Load raw data
# df = pd.read_csv('../data/raw/data.csv')
# df.head()

# %% [markdown]
# ## Clean and Process Data

# %%
# Data cleaning steps
# df = df.dropna()
# df.to_csv('../data/processed/data_clean.csv', index=False)
